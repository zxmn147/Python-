# %% [markdown]
# 作業題目:<br>
# 1. 在速度較慢的時候，可以先從哪邊開始檢查？
# 2. 資料過⼤時應採取什麼⽅式讓記憶體占⽤量下降？

# %% [markdown]
# 答:<br>
# 1. 先檢查有沒有使用到自訂義函數，如果有可以查詢pandas是否有支援相關演算法，如果以上都沒改善，可以從資料讀取的方式下手，將要讀取的資料轉成pkl檔。
# 2. 將欄位中的型態降級。

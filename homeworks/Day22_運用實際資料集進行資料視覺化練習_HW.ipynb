# %% [markdown]
# 目標: 使用 Seaborn 自帶的dataset, 利用 PANDAS 處理來繪製資料集的可視化圖表
#
# 重點: 不同型態的類別要套用的對應圖像是不一樣的
#
# (1) 做條形圖
#
# (2) 利用 facet grid 繪圖並分析
#
# 題目 : 取得另一個 dataset: titanic,
#
# 1. 將每個class中男性和女性的平均存活率用長形圖可視化
#
# 2. 瞭解性別在各艙等存活率的分布
#
# 3. 繪製堆疊條形圖，x軸代表依據艙等分成男性及女性，y軸代表人數，其中藍色代表死亡人數，橘色代表存活人數。
#
# 4. 瞭解性別在各艙等的存活率的分布 (PS: 跟第一次做 Face.Grid 有何不同??)

# %%
# 導入必要的程式庫
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# 取得資料集
df = sns.load_dataset('titanic')

# %%
# 將每個班級中男性和女性的平均存活率用長形圖可視化
'''
在這邊coding
sns.barplot
'''
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %% [markdown]
# [參考](https://blog.csdn.net/pigpigpig64/article/details/121108637)<br>
# PassengerId: 乘客ID<br>
# Survived: 是否生存，0代表遇难，1代表还活着<br>
# Pclass: 船舱等级：1Upper，2Middle，3Lower<br> Name: 姓名<br> Sex: 性别<br> Age: 年龄<br> SibSp: 兄弟姐妹及配偶个数<br> Parch:父母或子女个数<br> Ticket: 乘客的船票号<br> Fare: 乘客的船票价<br> Cabin: 乘客所在的仓位（位置）<br> Embarked:乘客登船口岸</p>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# 將每個班級中男性和女性的平均存活率用長形圖可視化
'''
在這邊coding
sns.barplot
'''
sns.barplot(x="sex", y="survived", hue="class", data=df)
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %% [markdown]
# 在上面的示例中,我們可以看到每個班級中男性和女性的平均存活率。從情節中,我們可以理解,女性存活人數比男性多。在男性和女性中,更多的存活率來自頭等艙。

# %% [markdown]
# 繪製數據子集的小倍數。 FacetGrid 示例,
#
# FacetGrid 類有助於可視化一個變數的分佈,以及使用多個面板在數據集子集中分別顯示多個變數之間的關係。

# %%
# 瞭解在各艙等不同性別的存活率
'''
在這邊coding
g = sns.FacetGrid
g.map
'''
g = sns.FacetGrid(data=df, col="pclass")
g.map(sns.barplot, 'sex', "survived", order=["male", "female"])

# %%
# 先檢視各艙位存活人數，此時可以使用groupby函數進行分類，
# 其中 survived＝1表示存活，survived＝0表示死亡，將survived加總即為各艙等生存人數。

df.groupby('pclass').survived.sum()
# Out:
# pclass
# 1    136
# 2     87
# 3    119
# Name: survived, dtype: int64

# %%
#加上性別
survived=df.groupby(['pclass','sex']).survived.sum()
survived
# Out:
# pclass  sex
# 1       female    91
#         male      45
# 2       female    70
#         male      17
# 3       female    72
#         male      47
# Name: survived, dtype: int64

# %%
survived.plot(kind='bar')
# Out:
# <Axes: xlabel='pclass,sex'>

# %%
# 使用pd.crosstab函數繪製交叉表，交叉表可以很直觀的依據艙位等級及性別來查看存活人數及死亡人數。
# 繪製堆疊條形圖，x軸代表依據艙等分成男性及女性，y軸代表人數，其中藍色代表死亡人數，橘色代表存活人數。
survived_counts = pd.crosstab([df.pclass, df.sex],df.survived)
survived_counts.index
# Out:
# MultiIndex([(1, 'female'),
#             (1,   'male'),
#             (2, 'female'),
#             (2,   'male'),
#             (3, 'female'),
#             (3,   'male')],
#            names=['pclass', 'sex'])

# %%
survived_counts
# Out:
# survived         0   1
# pclass sex
# 1      female    3  91
#        male     77  45
# 2      female    6  70
#        male     91  17
# 3      female   72  72
#        male    300  47

# %%
'''
在這邊coding
使用survived_counts.plot做對照組
'''
survived_counts.plot.bar(stacked=True)
# Out:
# <Axes: xlabel='pclass,sex'>

# %%
# 瞭解不同性別在各艙等的存活率
'''
在這邊coding
g = sns.FacetGrid
g.map
h = sns.FacetGrid
h.map
'''

g = sns.FacetGrid(data=df, col="sex")
g.map(sns.barplot, "pclass", "survived")
# Out:
# d:\Python_Data_Science_Marathon\venv\lib\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# PS: 跟第一次做 Face.Grid 有何不同??
# 切分的順序不同
'''
在這邊coding
g = sns.FacetGrid
g.map
'''
g = sns.FacetGrid(data=df, col="pclass")
g.map(sns.barplot, 'sex', "survived", order=["male", "female"])

# %% [markdown]
# 可以嘗試其他的參數對照組合
#
#  0   survived
#  1   pclass
#  2   sex
#  3   age
#  5   parch
#  6   fare
#  7   embarked
#  8   class
#  9   who
#  10  adult_male
#  11  deck
#  12  embark_town
#  13  alive
#  14  alone
